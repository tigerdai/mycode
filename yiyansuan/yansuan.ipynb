# %%
import pandas as pd
import tensorflow
import numpy

# %%
test_data = pd.read_csv('./data/jinnan_round1_testA_20181227.csv')
train_data = pd.read_csv('./data/jinnan_round1_train_20181227.csv')

# %%
train_data
# Out:
#              样本id   A1     A2     A3   A4        A5    A6        A7    A8  \
# 0     sample_1528  300    NaN  405.0  700  13:30:00  38.0       NaN   NaN
# 1     sample_1698  300    NaN  405.0  700  14:00:00  29.0       NaN   NaN
# 2      sample_639  300    NaN  405.0  700  14:00:00  29.0       NaN   NaN
# 3      sample_483  300    NaN  405.0  700   1:30:00  38.0       NaN   NaN
# 4      sample_617  300    NaN  405.0  700  22:00:00  29.0       NaN   NaN
# 5      sample_373  300    NaN  405.0  700   2:00:00  39.0   2:30:00  80.0
# 6      sample_577  300    NaN  405.0  700   8:00:00  29.0       NaN   NaN
# 7      sample_212  300    NaN  405.0  700   6:00:00  29.0       NaN   NaN
# 8      sample_521  300    NaN  405.0  700  17:30:00  21.0       NaN   NaN
# 9     sample_1026  300    NaN  405.0  700  11:00:00  21.0       NaN   NaN
# 10    sample_1743  300    NaN  405.0  700  14:00:00  29.0       NaN   NaN
# 11    sample_1493  300    NaN  405.0  700  21:00:00  37.0  21:20:00  80.0
# ...
