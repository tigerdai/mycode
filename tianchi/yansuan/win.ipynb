# %%
from sklearn import datasets
from sklearn.impute import SimpleImputer

import tensorflow as tf
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
#读取数据
train = pd.read_csv('data/jinnan_round1_train_20181227.csv')
train_x = train.iloc[:, list(range(1,43))]
train_y = train['result']

test = pd.read_csv('data/jinnan_round1_testA_20181227.csv')
test_x = train.iloc[:, list(range(1,43))]

# %%
#数据清洗
def clearn_data(data):
    #NAN值太多，直接删除列
    data = data.drop(['A2', 'A7', 'A8', 'B11'], axis=1)
    #fillna with mean value
    my_inputer = SimpleImputer(copy=False)
    data[['A1','A3','A4', 'A21', 'A23', 'B1', 'B2', 'B3', 'B8', 'B12', 'B13']] = my_inputer.fit_transform(data[['A1','A3','A4', 'A21', 'A23', 'B1', 'B2', 'B3', 'B8', 'B12', 'B13']])
    
    return data

#特征工程
def make_feature(data):
    return data

# %%
clearn_train = clearn_data(train)

# %%
train.describe()
# Out:
#                 A1     A2           A3           A4           A6          A8  \
# count  1396.000000   42.0  1354.000000  1396.000000  1396.000000  149.000000
# mean    298.853868  125.0   403.515510   705.974212    28.287751   78.818792
# std      10.130552    0.0    13.348093    53.214754     6.742765    2.683920
# min     200.000000  125.0   270.000000   470.000000    17.000000   70.000000
# 25%     300.000000  125.0   405.000000   700.000000    24.000000   80.000000
# 50%     300.000000  125.0   405.000000   700.000000    29.000000   80.000000
# 75%     300.000000  125.0   405.000000   700.000000    30.000000   80.000000
# max     300.000000  125.0   405.000000   980.000000    97.000000   82.000000
#
#                A10          A12          A13          A15          A17  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean    100.861032   102.641834     0.199907   103.829370   104.766905
# ...

# %%
train[train['A9'].notnull() == True]
# Out:
#         sample_id   A1     A2     A3   A4        A5    A6        A7    A8  \
# 0     sample_1528  300    NaN  405.0  700  13:30:00  38.0       NaN   NaN
# 1     sample_1698  300    NaN  405.0  700  14:00:00  29.0       NaN   NaN
# 2      sample_639  300    NaN  405.0  700  14:00:00  29.0       NaN   NaN
# 3      sample_483  300    NaN  405.0  700   1:30:00  38.0       NaN   NaN
# 4      sample_617  300    NaN  405.0  700  22:00:00  29.0       NaN   NaN
# 5      sample_373  300    NaN  405.0  700   2:00:00  39.0   2:30:00  80.0
# 6      sample_577  300    NaN  405.0  700   8:00:00  29.0       NaN   NaN
# 7      sample_212  300    NaN  405.0  700   6:00:00  29.0       NaN   NaN
# 8      sample_521  300    NaN  405.0  700  17:30:00  21.0       NaN   NaN
# 9     sample_1026  300    NaN  405.0  700  11:00:00  21.0       NaN   NaN
# 10    sample_1743  300    NaN  405.0  700  14:00:00  29.0       NaN   NaN
# 11    sample_1493  300    NaN  405.0  700  21:00:00  37.0  21:20:00  80.0
# ...

# %%
train[train['A7'].isnull()]
# Out:
#                 A1     A2           A3           A4           A6   A8  \
# count  1247.000000   42.0  1205.000000  1247.000000  1247.000000  0.0
# mean    298.716921  125.0   403.331950   706.688051    27.487330  NaN
# std      10.710965    0.0    14.139117    56.264264     6.169512  NaN
# min     200.000000  125.0   270.000000   470.000000    17.000000  NaN
# 25%     300.000000  125.0   405.000000   700.000000    24.000000  NaN
# 50%     300.000000  125.0   405.000000   700.000000    29.000000  NaN
# 75%     300.000000  125.0   405.000000   700.000000    29.000000  NaN
# max     300.000000  125.0   405.000000   980.000000    97.000000  NaN
#
#                A10          A12          A13          A15          A17  \
# count  1247.000000  1247.000000  1247.000000  1247.000000  1247.000000
# mean    100.963913   102.678428     0.199896   103.929270   104.997273
# std       0.904499     0.940463     0.002671     0.942062     1.265574
# ...

# %%
import os

# %%
os.path
# Out:
# <module 'ntpath' from 'D:\\Anaconda\\envs\\courtCrawl\\lib\\ntpath.py'>

# %%
col_info = pd.read_excel('col_info.xlsx')

# %%
col_info
# Out:
#           A1     A2     A3     A4  A5     A6  A7    A8  A9    A10   ...    B5  \
# value  300.0  125.0  400.0  700.0 NaN     30 NaN  80.0 NaN  100.0   ...   NaN
# range    NaN    NaN    NaN    NaN NaN  17-60 NaN   NaN NaN    NaN   ...   NaN
# total    NaN    NaN    NaN    NaN NaN    NaN NaN   NaN NaN    NaN   ...   NaN
# type     NaN    NaN    NaN    NaN NaN    NaN NaN   NaN NaN    NaN   ...   NaN
#
#           B6  B7     B8      B9     B10    B11            B12  \
# value     80 NaN     45      30      90     60          1200*
# range  40-80 NaN  20-73  30-120  60-120  30-90  4008009001200
# total    NaN NaN    NaN     NaN     NaN    NaN            NaN
# type     NaN NaN    NaN     NaN     NaN    NaN            NaN
#
#                     B13     B14
# value             0.15*     400
# range  0.003,0.006,0.15  40-460
# total               NaN     NaN
# type                NaN     NaN
#
# [4 rows x 42 columns]
