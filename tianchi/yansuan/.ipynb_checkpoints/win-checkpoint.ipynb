# %%
from sklearn import datasets
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
#读取数据
train = pd.read_csv('data/jinnan_round1_train_20181227.csv')
train_x = train.iloc[:, list(range(1,43))]
train_y = train['result']

test = pd.read_csv('data/jinnan_round1_testA_20181227.csv')
test_x = train.iloc[:, list(range(1,43))]

# %%
#数据清洗
def clearn_data(data):
    return data

# %%
#特征工程
def make_feature(data):
    return data

# %%
train.describe()
# Out:
#                 A1     A2           A3           A4           A6          A8  \
# count  1396.000000   42.0  1354.000000  1396.000000  1396.000000  149.000000
# mean    298.853868  125.0   403.515510   705.974212    28.287751   78.818792
# std      10.130552    0.0    13.348093    53.214754     6.742765    2.683920
# min     200.000000  125.0   270.000000   470.000000    17.000000   70.000000
# 25%     300.000000  125.0   405.000000   700.000000    24.000000   80.000000
# 50%     300.000000  125.0   405.000000   700.000000    29.000000   80.000000
# 75%     300.000000  125.0   405.000000   700.000000    30.000000   80.000000
# max     300.000000  125.0   405.000000   980.000000    97.000000   82.000000
#
#                A10          A12          A13          A15          A17  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean    100.861032   102.641834     0.199907   103.829370   104.766905
# ...

# %%
train.groupby(train['A3']).count()
# Out:
#        sample_id    A1  A2    A4    A5    A6   A7   A8    A9   A10   A11  \
# A3
# 270.0         12    12   0    12    12    12    0    0    12    12    12
# 340.0          6     6   0     6     6     6    0    0     6     6     6
# 405.0       1336  1336   0  1336  1336  1336  149  149  1336  1336  1336
#
#         A12   A13   A14   A15   A16   A17   A18   A19   A20   A21   A22   A23  \
# A3
# 270.0    12    12    12    12    12    12    12    12    12    12    12    12
# 340.0     6     6     6     6     6     6     6     6     6     6     6     6
# 405.0  1336  1336  1336  1336  1336  1336  1336  1336  1336  1334  1336  1333
#
#         A24   A25   A26   A27   A28    B1    B2    B3    B4    B5    B6    B7  \
# A3
# 270.0    12    12    12    12    12    12    12    12    12    12    12    12
# 340.0     6     6     6     6     6     6     6     6     6     6     6     6
# 405.0  1335  1336  1334  1336  1336  1326  1334  1334  1336  1335  1336  1336
#
# ...

# %%
train[train['B11'].notnull()]
# Out:
#         sample_id   A1  A2     A3   A4        A5    A6   A7  A8        A9  \
# 1     sample_1698  300 NaN  405.0  700  14:00:00  29.0  NaN NaN  16:00:00
# 2      sample_639  300 NaN  405.0  700  14:00:00  29.0  NaN NaN  16:00:00
# 4      sample_617  300 NaN  405.0  700  22:00:00  29.0  NaN NaN   0:00:00
# 6      sample_577  300 NaN  405.0  700   8:00:00  29.0  NaN NaN  10:00:00
# 7      sample_212  300 NaN  405.0  700   6:00:00  29.0  NaN NaN   8:00:00
# 10    sample_1743  300 NaN  405.0  700  14:00:00  29.0  NaN NaN  16:00:00
# 13     sample_621  300 NaN  405.0  700   6:00:00  29.0  NaN NaN   8:00:00
# 14    sample_1269  300 NaN  405.0  700   6:00:00  29.0  NaN NaN   8:00:00
# 16    sample_1736  300 NaN  405.0  700   6:00:00  29.0  NaN NaN   8:00:00
# 17      sample_97  300 NaN  405.0  700  16:00:00  29.0  NaN NaN  18:00:00
# 18     sample_642  300 NaN  405.0  700  14:00:00  29.0  NaN NaN  16:00:00
# 19     sample_179  300 NaN  405.0  700  14:00:00  29.0  NaN NaN  16:00:00
# ...
